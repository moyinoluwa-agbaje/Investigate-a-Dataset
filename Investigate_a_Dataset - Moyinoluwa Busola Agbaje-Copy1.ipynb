# %% [markdown]
# # Project: Investigate a Dataset - [TMdb Movies]
#
# >By: Moyinoluwa Busola Agbaje
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# ### Dataset Description
#
# > This dataset contains information about 10,000 movies collected from the Movies Database (TMdb), including user ratings and revenue. The columns in this dataset are;
#
# <ol>
# <li>id</li>
# <li>imdb_id</li>
# <li>popularity</li>
# <li>budget</li>
# <li>revenue</li>
# <li>original_title</li>
# <li>cast</li>
# <li>homepage</li>
# <li>director</li>
# <li>tagline</li>
# <li>keywords</li>
# <li>overview</li>
# <li>runtime</li>
# <li>genres</li>
# <li>production_companies</li>
# <li>release_date</li>
# <li>vote_count</li>
# <li>vote_average</li>
# <li>release_year</li>
# <li>budget_adj</li>
# <li>revenue_adj</li>
# </ol>
#
# > In the course of my analysis, some of the columns will be formatted to fit into my explorations which will include deletion of columns that won't be needed. Further, the last two columns that ends with '_adj' shows the budget and revenue of the associated movies in terms of 2010 dollars, accounting for inflation over.
#
# > My analysis will use Pandas, Numpy, and Matplotlib libaries.
#
#
# ### Question(s) for Analysis
#
# The following questions will be queried and answered in the course of the Data Analysis for this project, amongst others.
#
# <ul>
# <li>Statistical Analysis.</li>
# <li>Percentage distribution of genres.</li>
# <li>Relationship between runtime and average vote.</li>
# <li>Correlation between average vote, release year and popularity of movies.</li>
# </ul>

# %%
# import statements for all of the packages and libaries to be used

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# ### Data Loading
#
# > Here, I'll load my data, check for cleanliness, and then trim and clean the dataset for my analysis. I downloaded the dataset on my PC, uploaded to the VM workspace, then called the path for importing.

# %%
# Load your data and print out a few lines. Perform operations to inspect data
#   types and look for instances of missing or possibly errant data.

df_movies = pd.read_csv(r'C:\Users\c_agbajmoy\Documents\ALX-Udacity\PROJECT 1\home\Database_TMDb_movie_data\tmdb-movies.csv')
df_movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %% [markdown]
# ### Data Cleaning

# %%
# get the descriptive analysis/information of the columns in the dataset

df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
# get the dimension of the dataset

df_movies.shape
# Out:
# (10866, 21)

# %%
# check for any duplicate record(s)

df_movies.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10861    False
# 10862    False
# 10863    False
# 10864    False
# 10865    False
# Length: 10866, dtype: bool

# %%
# count of duplicate should there's any in the dataset

sum(df_movies.duplicated())
# Out:
# 1

# %% [markdown]
# The duplicate value returns 1 which won't be needed in the records.

# %%
# dropping the duplicate value

df_movies.drop_duplicates(inplace=True)
df_movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
# check for count of null values in the columns

df_movies.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7929
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %% [markdown]
# Nine (9) columns had NaN values from the isnull() function above.

# %%
df_movies.isnull().any(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10861     True
# 10862     True
# 10863     True
# 10864     True
# 10865     True
# Length: 10865, dtype: bool

# %% [markdown]
# #### Removing unwanted columns off the table for better exploration and analysis. Also, the last two columns with '_adj' will be adjusted to avoid possible mixup or confusion.

# %%
# remove unwanted columns for better exploration and analysis usin the drop() function

df_movies.drop(['imdb_id', 'homepage', 'budget', 'revenue', 'tagline', 'overview', 'release_date', 'keywords'], axis=1, inplace=True)

# %%
# check how the dataframe looks like after taking off unwanted columns

df_movies.head()
# Out:
#        id  popularity                original_title  \
# 0  135397   32.985763                Jurassic World
# 1   76341   28.419936            Mad Max: Fury Road
# 2  262500   13.112507                     Insurgent
# 3  140607   11.173104  Star Wars: The Force Awakens
# 4  168259    9.335014                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
# 1      120  Action|Adventure|Science Fiction|Thriller
# 2      119         Adventure|Science Fiction|Thriller
# ...

# %%
# check for any missing values again should all initial ones weren't eliminated

df_movies.isnull().sum()
# Out:
# id                         0
# popularity                 0
# original_title             0
# cast                      76
# director                  44
# runtime                    0
# genres                    23
# production_companies    1030
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %% [markdown]
# Four (4) entries are still been affected with null values.

# %%
# remove the records with the null values

df_movies.dropna(inplace = True)
df_movies.head()
# Out:
#        id  popularity                original_title  \
# 0  135397   32.985763                Jurassic World
# 1   76341   28.419936            Mad Max: Fury Road
# 2  262500   13.112507                     Insurgent
# 3  140607   11.173104  Star Wars: The Force Awakens
# 4  168259    9.335014                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
# 1      120  Action|Adventure|Science Fiction|Thriller
# 2      119         Adventure|Science Fiction|Thriller
# ...

# %%
# check the dimension of the dataframe after taking off all excesses

df_movies.shape
# Out:
# (9772, 13)

# %%
# check for any null values again to be sure all have been cleared

df_movies.isnull().sum()
# Out:
# id                      0
# popularity              0
# original_title          0
# cast                    0
# director                0
# runtime                 0
# genres                  0
# production_companies    0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# dtype: int64

# %% [markdown]
# No more null values in any of the column entries, and also the dimenson of the dataframe has been reduced to
# (9772, 13) from the initial (10866, 21).

# %%
# adjusting/renaming the last 2 columns with (_adj) for easy reference and use

new_labels = []
for col in df_movies.columns:
    if '_adj' in col:
        new_labels.append(col[:-4])
    else:
        new_labels.append(col)

# %%
# check the renaming of the adjusted columns

new_labels
# Out:
# ['id',
#  'popularity',
#  'original_title',
#  'cast',
#  'director',
#  'runtime',
#  'genres',
#  'production_companies',
#  'vote_count',
#  'vote_average',
#  'release_year',
#  'budget',
#  'revenue']

# %%
df_movies.columns = new_labels
df_movies.head()
# Out:
#        id  popularity                original_title  \
# 0  135397   32.985763                Jurassic World
# 1   76341   28.419936            Mad Max: Fury Road
# 2  262500   13.112507                     Insurgent
# 3  140607   11.173104  Star Wars: The Force Awakens
# 4  168259    9.335014                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
# 1      120  Action|Adventure|Science Fiction|Thriller
# 2      119         Adventure|Science Fiction|Thriller
# ...

# %%
# check updated information about the dataframe

df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9772 entries, 0 to 10865
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9772 non-null   int64
#  1   popularity            9772 non-null   float64
#  2   original_title        9772 non-null   object
#  3   cast                  9772 non-null   object
#  4   director              9772 non-null   object
#  5   runtime               9772 non-null   int64
#  6   genres                9772 non-null   object
#  7   production_companies  9772 non-null   object
#  8   vote_count            9772 non-null   int64
#  9   vote_average          9772 non-null   float64
#  10  release_year          9772 non-null   int64
#  11  budget                9772 non-null   float64
#  12  revenue               9772 non-null   float64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 1.0+ MB

# %%
# check the descriptive analysis of the dataframe columns

df_movies.describe()
# Out:
#                   id   popularity      runtime   vote_count  vote_average  \
# count    9772.000000  9772.000000  9772.000000  9772.000000   9772.000000
# mean    63189.640810     0.694721   102.926627   239.312014      5.963528
# std     90718.059987     1.036931    27.877432   603.011504      0.913174
# min         5.000000     0.000188     0.000000    10.000000      1.500000
# 25%     10221.500000     0.232710    90.000000    18.000000      5.400000
# 50%     18677.500000     0.419762   100.000000    46.000000      6.000000
# 75%     70577.250000     0.776408   112.000000   173.000000      6.600000
# max    417859.000000    32.985763   877.000000  9767.000000      8.700000
#
#        release_year        budget       revenue
# count   9772.000000  9.772000e+03  9.772000e+03
# mean    2000.878428  1.941599e+07  5.705309e+07
# std       13.036794  3.566634e+07  1.514499e+08
# min     1960.000000  0.000000e+00  0.000000e+00
# 25%     1994.000000  0.000000e+00  0.000000e+00
# ...

# %% [markdown]
# From the statistical description above, it's shown that the minimum runtime, budget, and revenue is 0. Also the 25% confidence level for budget and revenue is 0. Hence, there's a need to clean up the invalid records and do a rerun on the statistics.

# %%
# cleaning for invalid data as mentioned above

zero_record = df_movies.query('budget == 0 or revenue == 0').index
df_movies.drop(zero_record, axis=0, inplace=True)

# %%
# show the updated statistical description after removing zero values

df_movies.describe()
# Out:
#                   id   popularity      runtime   vote_count  vote_average  \
# count    3805.000000  3805.000000  3805.000000  3805.000000   3805.000000
# mean    40040.372668     1.203784   109.351117   534.159001      6.170565
# std     67585.708616     1.480569    19.845678   883.757588      0.792437
# min         5.000000     0.010335    15.000000    10.000000      2.200000
# 25%      5925.000000     0.470651    96.000000    74.000000      5.700000
# 50%     11253.000000     0.810805   106.000000   209.000000      6.200000
# 75%     38579.000000     1.387163   119.000000   584.000000      6.700000
# max    417859.000000    32.985763   338.000000  9767.000000      8.400000
#
#        release_year        budget       revenue
# count   3805.000000  3.805000e+03  3.805000e+03
# mean    2001.229172  4.471977e+07  1.387159e+08
# std       11.329616  4.488697e+07  2.169973e+08
# min     1960.000000  9.693980e-01  2.370705e+00
# 25%     1995.000000  1.354637e+07  1.925371e+07
# ...

# %% [markdown]
# I can proceed to EDA now that my data is adequately and appropraitely ready.

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
#
# ### Research Question 1 - Which column(s) have right skewness?

# %%
# view all numerical columns in a dataframe using the hist function to check the most right-skewed attributes

df_movies.hist(figsize= (14, 10), color='red');

# %% [markdown]
# From above representations, the columns that have right skewness are 'release_year', 'runtime' and 'vote_average'

# %% [markdown]
# ### Research Question 2 -  What is the percentage distribution of genres?

# %%
# define a holder for the genres column and pick two random columns for the representation

df_genres1 = df_movies[['genres', 'popularity', 'release_year']]
df_genres1.head()
# Out:
#                                       genres  popularity  release_year
# 0  Action|Adventure|Science Fiction|Thriller   32.985763          2015
# 1  Action|Adventure|Science Fiction|Thriller   28.419936          2015
# 2         Adventure|Science Fiction|Thriller   13.112507          2015
# 3   Action|Adventure|Science Fiction|Fantasy   11.173104          2015
# 4                      Action|Crime|Thriller    9.335014          2015

# %% [markdown]
# I want to split the genres column above into different rows in order to remove the '|'

# %%
# split the entries above one genres into different rows

from itertools import chain

# return list from the series of '|'

def chainer(s):
    return list(chain.from_iterable(s.str.split('|')))

# %%
df_genres1.head()
# Out:
#                                       genres  popularity  release_year
# 0  Action|Adventure|Science Fiction|Thriller   32.985763          2015
# 1  Action|Adventure|Science Fiction|Thriller   28.419936          2015
# 2         Adventure|Science Fiction|Thriller   13.112507          2015
# 3   Action|Adventure|Science Fiction|Fantasy   11.173104          2015
# 4                      Action|Crime|Thriller    9.335014          2015

# %%
# get the length of the split

lnth = df_movies.genres.str.split('|').map(len)

# create new dataframe to map the chaining above

df_genres1 = pd.DataFrame({'release_year': np.repeat(df_genres1['release_year'], lnth),
                            'genres': chainer(df_genres1['genres']),
                            'popularity': np.repeat(df_genres1['popularity'], lnth)})

df_genres1.head()
# Out:
#    release_year           genres  popularity
# 0          2015           Action   32.985763
# 0          2015        Adventure   32.985763
# 0          2015  Science Fiction   32.985763
# 0          2015         Thriller   32.985763
# 1          2015           Action   28.419936

# %%
# plotting the pie chart of genres

df_genres1['genres'].value_counts().plot(kind='pie', figsize=(10, 10))
plt.title('Percentage distribution of Genres')
# Out:
# Text(0.5,1,'Percentage distribution of Genres')

# %%
# define a selection function

def function(picker):
    return picker.loc[picker['popularity'] == picker['popularity'].max()]

# %%
# get the mean popularity per genre in each year

df_poplr = df_genres1.groupby(['release_year', 'genres'], as_index=False).mean()
df_poplr.head(10)
# Out:
#    release_year     genres  popularity
# 0          1960     Action    1.504538
# 1          1960  Adventure    1.872132
# 2          1960     Comedy    0.501564
# 3          1960      Drama    1.564871
# 4          1960    History    1.136943
# 5          1960     Horror    2.610362
# 6          1960    Romance    0.501564
# 7          1960   Thriller    2.610362
# 8          1960    Western    1.872132
# 9          1961     Action    0.464139

# %%
# computing the most popular genres per year

df_most_pop = df_poplr.groupby('release_year', as_index=False).apply(function).reset_index(drop=True)
df_most_pop.head()
# Out:
#    release_year     genres  popularity
# 0          1960     Horror    2.610362
# 1          1960   Thriller    2.610362
# 2          1961  Animation    2.631987
# 3          1962   Thriller    3.170651
# 4          1963  Adventure    1.586280

# %%
# draw pie chart of genres with setting labels and values

df_most_pop = df_poplr.groupby('release_year', as_index=False).apply(function).reset_index(drop=True)

sizes = df_most_pop.genres.value_counts().values
labels = df_most_pop.genres.value_counts().index

fig1, ax1 = plt.subplots(figsize=(8,8))
ax1.pie(sizes, labels=labels, autopct='%1.0f%%')
ax1.axis('equal')
plt.title('Percentage per genres category')

plt.show();

# %% [markdown]
# ### Research Question 3 - What is the relationship between runtime and average vote?

# %%
# scatter plot to show the relationship between runtime and average vote columns

df_movies.plot(x= 'vote_average', y= 'runtime', kind='scatter', color='blue', figsize=(9,9))
plt.title('Relationship between Average Vote and Runtime')
plt.xlabel('Vote Casted')
plt.ylabel('Runtime (mins)');

# %% [markdown]
# From the above scatter plot illustration, it's seen that the runtime around 100 mins and above have the best votes. This tells that from runtime of 0-99 mins have lower votes compared to those of 100 mins and above. Apparently, this show that the higher the runtime of a movies/movies, the higher the number of votes.

# %% [markdown]
# ### Research Question 4 -  What is the correlation between average vote, release year and popularity?

# %% [markdown]
# From the scatter plot above, it's observed that the relationship between runtime and averge vote is weaker. This is becuase the higher the runtime, the higher the vote, and this shows that the longest runtime movies have higher average vote. This doesn't seem to be a good decisive tool between both variables.

# %%
# plot the relationship between vote average and popularity

df_movies.plot(x='vote_average', y='popularity', kind='scatter', color='orange', alpha=1)
plt.title('Vote Average vs Popularity')
plt.show()

# %% [markdown]
# The scatter plot above shows that both columns are positively correlated.

# %%
# grouping new data frame into new variable release year
# the dataframe will group the movies by release year

df_annually = df_movies.groupby('release_year').mean()
df_annually.head()
# Out:
#                         id  popularity     runtime  vote_count  vote_average  \
# release_year
# 1960           4345.800000    1.324513  130.000000  372.600000      7.400000
# 1961          11003.900000    0.787718  132.500000  191.400000      6.620000
# 1962           3977.428571    0.983485  141.285714  229.428571      6.900000
# 1963           7969.166667    1.040612  153.500000  262.333333      6.766667
# 1964           4150.285714    1.377790  122.428571  343.428571      6.971429
#
#                     budget       revenue
# release_year
# 1960          3.068179e+07  1.902299e+08
# 1961          2.818516e+07  2.463622e+08
# 1962          4.062476e+07  2.124740e+08
# 1963          7.252496e+07  2.094838e+08
# 1964          3.408189e+07  3.300344e+08

# %%
# plot average vote by release year based on the new dataframe created above

plt.bar(df_annually.index, df_annually['vote_average'], color='purple', alpha=0.5)
plt.title('Vote Average by Release Year')
plt.xlabel('Release Year')
plt.ylabel('Vote Average')
plt.show()

# %% [markdown]
# From the bar chart plotted above, a downward slope decline can be observed. It can then be said that the most voted movies were released between year 1960 and 1980s, and popularity between 0 and 5 have progressing mid-high vote.

# %% [markdown]
# # Conclusions

# %% [markdown]
# While working with 'The Movies database ' in this project, I was able to explore the dataset by analyzing qualities and identify the properties associated with popularity of movies.
#
# After I cleaned the dataset by removing unwanted, null, and duplicated values, I went further to check the columns that have the most right skewness. Also, I inspected the percentage distribution of the genres attribute to establish the genre with the highest percentage. From the pie chart represented, the 'Animation', 'Fantasy' and 'Adventure' respectively had the highest percentages distribution over the year. Other genres such as 'Thriller' and 'History' appeared lesser to become the most popular genre.
#
# Right after the processes above, I checked the relationship between runtime and average vote.
#
# Finaly, I checked the correlation between average vote, release year and popularity. Higher evenly distribution was noticed with the 'vote_average' column, and this in turn made me plot few charts. From the plotted charts, the most voted movies were released between year 1960 and the 1980s, with popularity rating of 0 and 5 with progrssing mid-high vote.

# %% [markdown]
# # Limitations

# %% [markdown]
# Although the dataset was exploratory to work with, however the issues I encountered during my analysis was that, nine (9) columns had heavy NaN values as well as one (1) duplicated record in the data.
#
# Also, the number of rows and columns reduced from (10866,21) to (9773, 13) repectively due to the thorough cleanup done on the dataset.
#
# The most challenge I encountere was getting my most popular genre category and plotting the respective visual. I got stuck and had to leave the cells.
#
# Finally, splitting the 'genres' column took time as I ran into errors which became exhausting at some point. I got a feedback fro the Team to review my project, after which I did the necessary debugging and my blocker codes ran successfully well.

# %% [markdown]
# # References

# %% [markdown]
# https://stackoverflow.com/questions/37333299/splitting-a-pandas-dataframe-column-by-delimiter

# %% [markdown]
# https://stackoverflow.com/questions/14247586/how-to-select-rows-with-one-or-more-nulls-from-a-pandas-dataframe-without-listin

# %% [markdown]
# https://stackoverflow.com/questions/24560298/python-numpy-valueerror-operands-could-not-be-broadcast-together-with-shapes

# %% [markdown]
# https://stackoverflow.com/questions/28395005/nameerror-name-func-is-not-defined
